# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt
from surprise import SVDpp
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from collections import defaultdict
from surprise.model_selection import train_test_split 
from sklearn.model_selection import train_test_split 
from sklearn.metrics import roc_auc_score
# Out:
# /Users/kanupriyaarora/opt/anaconda3/lib/python3.8/site-packages/pandas/core/computation/expressions.py:20: UserWarning: Pandas requires version '2.7.3' or newer of 'numexpr' (version '2.7.2' currently installed).
#   from pandas.core.computation.check import NUMEXPR_INSTALLED

# %%
#reading files
df_books = pd.read_csv('goodreads_books_poetry.csv')
df_users = pd.read_csv('goodreads_interactions_poetry.csv')

# %%
df_users.columns
# Out:
# Index(['user_id', 'book_id', 'review_id', 'is_read', 'rating',
#        'review_text_incomplete', 'date_added', 'date_updated', 'read_at',
#        'started_at'],
#       dtype='object')

# %%
df_books = df_books[df_books['language_code'] == 'eng']

# %%
df_books.shape
# Out:
# (8393, 29)

# %%
# Extract the unique book_id values from df_books
valid_book_ids = df_books['book_id'].unique()

# Filter the rows in df_users
df_users = df_users[df_users['book_id'].isin(valid_book_ids)]

# %%
df_users.head()
# Out:
#                             user_id   book_id  \
# 0  8842281e1d1347389f2ab93d60773d4d      1384
# 1  8842281e1d1347389f2ab93d60773d4d      1376
# 2  8842281e1d1347389f2ab93d60773d4d     30119
# 3  72fb0d0087d28c832f15776b0d936598  24769928
# 4  72fb0d0087d28c832f15776b0d936598     30119
#
#                           review_id  is_read  rating review_text_incomplete  \
# 0  1bad0122cebb4aa9213f9fe1aa281f66     True       4                    NaN
# 1  eb6e502d0c04d57b43a5a02c21b64ab4     True       4                    NaN
# 2  787564bef16cb1f43e0f641ab59d25b7     True       5                    NaN
# 3  8c80ee74743d4b3b123dd1a2e0c0bcac    False       0                    NaN
# 4  2a83589fb597309934ec9b1db5876aaf     True       3                    NaN
#
#                        date_added                    date_updated  \
# 0  Wed May 09 09:33:44 -0700 2007  Wed May 09 09:33:44 -0700 2007
# 1  Wed May 09 09:33:18 -0700 2007  Wed May 09 09:33:18 -0700 2007
# 2  Sat Jan 13 13:44:20 -0800 2007  Wed Mar 22 11:45:08 -0700 2017
# 3  Wed Apr 27 11:05:51 -0700 2016  Wed Apr 27 11:05:52 -0700 2016
# 4  Mon Jun 04 18:58:08 -0700 2012  Mon Jun 04 18:58:13 -0700 2012
#
#                           read_at started_at
# 0                             NaN        NaN
# 1                             NaN        NaN
# 2  Tue Mar 01 00:00:00 -0800 1983        NaN
# 3                             NaN        NaN
# 4                             NaN        NaN

# %%
df_users=df_users[['user_id', 'book_id', 'rating']]

# %%
df_users.head()
# Out:
#                             user_id   book_id  rating
# 0  8842281e1d1347389f2ab93d60773d4d      1384       4
# 1  8842281e1d1347389f2ab93d60773d4d      1376       4
# 2  8842281e1d1347389f2ab93d60773d4d     30119       5
# 3  72fb0d0087d28c832f15776b0d936598  24769928       0
# 4  72fb0d0087d28c832f15776b0d936598     30119       3

# %%
#splitting data into train and test sets
train_split, test_split = train_test_split(df_users, test_size = 0.25, random_state = 20)
print("Training data size:", train_split.shape)
print("Test data size:", test_split.shape)
# Out:
# Training data size: (1014663, 3)
# Test data size: (338221, 3)

# %%
#reader for parsing the ratings file
reader = Reader(rating_scale=(1, 5))
#building the train and test set, loading the data from dataframe 
train_build = Dataset.load_from_df(train_split, reader)
test_build = Dataset.load_from_df(test_split, reader)
trainset = train_build.build_full_trainset()
testset = test_build.build_full_trainset().build_testset() 
print("Test set size:", len(testset))
# Out:
# Test set size: 338221

# %%
#model building
#takes in factors, epochs, learning rate and regularization parameter 
model = SVDpp(n_factors=30,n_epochs=20,lr_all=0.01,reg_all=0.05) 
model.fit(trainset)

# %%
#making predictions
predictions = model.test(testset)
#calculating rmse
accuracy.rmse(predictions, verbose = True)
#Save all the predicted ratings and convert it to a dataframe
# Out:
# RMSE: 1.8000
# 1.8000174327805702

# %%
all_recommendations_list = defaultdict(list)
all_recommendations_df = pd.DataFrame([])
# Create empty lists to collect data for each column
user_list = []
book_id_list = []
predicted_rating_list = []

for uid, iid, true_r, est, _ in predictions:
    all_recommendations_list[uid].append((iid, est))
    user_list.append(uid)
    book_id_list.append(iid)
    predicted_rating_list.append(est)


#for uid, iid, true_r, est, _ in predictions:
    #all_recommendations_list[uid].append((iid, est))
    
# Create a DataFrame using the collected data
all_recommendations_df = pd.DataFrame({'user': user_list, 'book_id': book_id_list, 'predicted_rating': predicted_rating_list})
    #all_recommendations_df = all_recommendations_df.append(pd.DataFrame({'user': uid, 'movieId': iid, 'predicted_rating' : est}, index=[0]), ignore_index=True); 
print(all_recommendations_df.head(5)) 
print(all_recommendations_df.shape)
# Out:
#                                user   book_id  predicted_rating
# 0  95c25c4181bd7449f1ce2e2dafe7c21e     30119          2.139957
# 1  091402d81bef94103c1ef99586c4d365     27822          1.904122
# 2  091402d81bef94103c1ef99586c4d365      1420          2.035555
# 3  c958665f697b9b750102b28d61680a0b  18263725          2.550888
# 4  a8e23ebfd310fc499af43ace51b1c894      1715          2.794470
# (338221, 3)

# %%
#Merging with movies file to get genre, title information for predictions
all_recommendations_df_details = pd.merge(all_recommendations_df,df_books, on='book_id', how='inner') 
print(all_recommendations_df_details.head(5))
# Out:
#                                user  book_id  predicted_rating        isbn  \
# 0  95c25c4181bd7449f1ce2e2dafe7c21e    30119          2.139957  0060513039
# 1  a8e23ebfd310fc499af43ace51b1c894    30119          2.895295  0060513039
# 2  a5b0434e1f3179930816fea2b9193b6e    30119          2.814852  0060513039
# 3  238dcb73b558f030afd477ed6be48232    30119          3.612540  0060513039
# 4  87070937fd0a8f99c7dd0dfceef7ee37    30119          1.094194  0060513039
#
#    text_reviews_count series country_code language_code  \
# 0                8950     []           US           eng
# 1                8950     []           US           eng
# 2                8950     []           US           eng
# 3                8950     []           US           eng
# 4                8950     []           US           eng
#
#                                      popular_shelves asin  ...         isbn13  \
# 0  [{'count': '20447', 'name': 'to-read'}, {'coun...  NaN  ...  9780060513030
# 1  [{'count': '20447', 'name': 'to-read'}, {'coun...  NaN  ...  9780060513030
# 2  [{'count': '20447', 'name': 'to-read'}, {'coun...  NaN  ...  9780060513030
# 3  [{'count': '20447', 'name': 'to-read'}, {'coun...  NaN  ...  9780060513030
# 4  [{'count': '20447', 'name': 'to-read'}, {'coun...  NaN  ...  9780060513030
#
#    publication_month edition_information publication_year  \
# 0               11.0                 NaN           2002.0
# 1               11.0                 NaN           2002.0
# 2               11.0                 NaN           2002.0
# 3               11.0                 NaN           2002.0
# 4               11.0                 NaN           2002.0
#
#                                                  url  \
# 0  https://www.goodreads.com/book/show/30119.Wher...
# 1  https://www.goodreads.com/book/show/30119.Wher...
# 2  https://www.goodreads.com/book/show/30119.Wher...
# 3  https://www.goodreads.com/book/show/30119.Wher...
# 4  https://www.goodreads.com/book/show/30119.Wher...
#
#                                            image_url ratings_count work_id  \
# 0  https://images.gr-assets.com/books/1168052448m...       1029527   30518
# 1  https://images.gr-assets.com/books/1168052448m...       1029527   30518
# 2  https://images.gr-assets.com/books/1168052448m...       1029527   30518
# 3  https://images.gr-assets.com/books/1168052448m...       1029527   30518
# 4  https://images.gr-assets.com/books/1168052448m...       1029527   30518
#
#                      title     title_without_series
# 0  Where the Sidewalk Ends  Where the Sidewalk Ends
# 1  Where the Sidewalk Ends  Where the Sidewalk Ends
# 2  Where the Sidewalk Ends  Where the Sidewalk Ends
# 3  Where the Sidewalk Ends  Where the Sidewalk Ends
# 4  Where the Sidewalk Ends  Where the Sidewalk Ends
#
# [5 rows x 31 columns]

# %%
all_recommendations_df_details.columns
# Out:
# Index(['user', 'book_id', 'predicted_rating', 'isbn', 'text_reviews_count',
#        'series', 'country_code', 'language_code', 'popular_shelves', 'asin',
#        'is_ebook', 'average_rating', 'kindle_asin', 'similar_books',
#        'description', 'format', 'link', 'authors', 'publisher', 'num_pages',
#        'publication_day', 'isbn13', 'publication_month', 'edition_information',
#        'publication_year', 'url', 'image_url', 'ratings_count', 'work_id',
#        'title', 'title_without_series'],
#       dtype='object')

# %%
#List of top n recommendations list as per SVD++
def get_top_n_recommendation_list_df(all_recommendations_df_details, n=10):
    top_n_recommendations_df = all_recommendations_df_details.sort_values(['user','predicted_rating'] ,ascending=[True, False])
    return top_n_recommendations_df

# %%
top_n_recommendations_df = get_top_n_recommendation_list_df(all_recommendations_df_details, 10) 
print(top_n_recommendations_df.head())
# Out:
#                                     user   book_id  predicted_rating  \
# 257732  0001085188e302fc6b2568de45a5f56b  32334098          1.000000
# 274369  00013344a98d0147eacab88d3e1502ef    138165          4.965609
# 191271  00013344a98d0147eacab88d3e1502ef      5932          4.689238
# 106610  000192962b87d560f00b06fdcbd71681     30118          5.000000
# 83978   000243c8e211fb3f359e4ff45ca899ea     15997          1.000000
#
#               isbn  text_reviews_count       series country_code  \
# 257732  144948641X                 221  ['1137480']           US
# 274369  0393974979                  19           []           US
# 191271  0143039962                 882           []           US
# 106610  0060513063                2222           []           US
# 83978   0140424393                2098   ['465549']           US
#
#        language_code                                    popular_shelves asin  \
# 257732           eng  [{'count': '62826', 'name': 'to-read'}, {'coun...  NaN
# 274369           eng  [{'count': '1079', 'name': 'to-read'}, {'count...  NaN
# 191271           eng  [{'count': '890', 'name': 'to-read'}, {'count'...  NaN
# 106610           eng  [{'count': '95074', 'name': 'to-read'}, {'coun...  NaN
# 83978            eng  [{'count': '7151', 'name': 'currently-reading'...  NaN
#
#         ...         isbn13  publication_month  \
# 257732  ...  9781449486419                2.0
# 274369  ...  9780393974973                3.0
# 191271  ...  9780143039969               12.0
# 106610  ...  9780060513061               10.0
# 83978   ...  9780140424393                2.0
#
#                      edition_information publication_year  \
# 257732                               NaN           2017.0
# 274369                               NaN           2000.0
# 191271                               NaN           2006.0
# 106610  20th Anniversary Edition with CD           2002.0
# 83978                                NaN           2003.0
#
#                                                       url  \
# 257732  https://www.goodreads.com/book/show/32334098-t...
# 274369  https://www.goodreads.com/book/show/138165.Poe...
# 191271  https://www.goodreads.com/book/show/5932.Twent...
# 106610  https://www.goodreads.com/book/show/30118.A_Li...
# 83978   https://www.goodreads.com/book/show/15997.Para...
#
#                                                 image_url ratings_count  \
# 257732  https://images.gr-assets.com/books/1487511102m...          1049
# 274369  https://s.gr-assets.com/assets/nophoto/book/11...          2573
# 191271  https://images.gr-assets.com/books/1447622711m...         32000
# 106610  https://images.gr-assets.com/books/1427169918m...        304689
# 83978   https://images.gr-assets.com/books/1455618673m...         97784
#
#          work_id                                    title  \
# 257732  50494177   The Princess Saves Herself in This One
# 274369    133178                  Poetry, Drama and Prose
# 191271   2103337  Twenty Love Poems and a Song of Despair
# 106610    142009                     A Light in the Attic
# 83978    1031493                            Paradise Lost
#
#                            title_without_series
# 257732   The Princess Saves Herself in This One
# 274369                  Poetry, Drama and Prose
# 191271  Twenty Love Poems and a Song of Despair
# 106610                     A Light in the Attic
# 83978                             Paradise Lost
#
# [5 rows x 31 columns]

# %%
metrics=[]
true_positives_array = []
est_array = []
for rating_threshold in np.arange(0,5.5,0.5):
    truePositives = 0
    trueNegatives = 0
    falseNegatives = 0
    falsePositives = 0
    accuracy =0
    precision =0
    recall =0
    f1_score = 0
    for uid,_, true_r, est, _ in predictions:
        if(true_r >= rating_threshold and est >= rating_threshold):
            truePositives = truePositives + 1 
            true_positives_array.append(true_r) 
            est_array.append(est)
#here
        elif(true_r >= rating_threshold and est<= rating_threshold):
            falseNegatives = falseNegatives + 1 
        elif(true_r <= rating_threshold and est >=rating_threshold):
             falsePositives = falsePositives + 1 
        elif(true_r <= rating_threshold and est<=rating_threshold):
            trueNegatives = trueNegatives + 1 
        if(truePositives > 0):
            accuracy = (truePositives + trueNegatives ) / (truePositives + trueNegatives + falsePositives + falseNegatives)
            precision = truePositives / (truePositives + falsePositives)
            recall = truePositives / (truePositives + falseNegatives) 
            f1_score = 2 * (precision * recall) / (precision + recall)

# %%
metrics.append([rating_threshold,truePositives,trueNegatives,falsePositives,falseNegatives,accuracy,precision,recall,f1_score])
metrics_df = pd.DataFrame(metrics)
metrics_df.rename(columns={0:'rating_threshold', 1:'truePositives', 2: 'trueNegatives', 3: 'falsePositives', 4:'falseNegatives', 5: 'Accuracy', 6: 'Precision', 7:'Recall', 8:'F1 Score'},inplace=True)
true_bin_array =[]
for x in true_positives_array:
    if x >= rating_threshold: 
        x=1
    else: 
        x=0
    true_bin_array.append(x)
auc_score =roc_auc_score(true_bin_array,est_array,multi_class='raise',average='macro')
print('AUC Score: ',auc_score)
# Out:
# AUC Score:  0.6888907278757329

# %%
#Calculate precision and recall at n
def get_precision_recall_at_n(predictions,topn,rating_threshold): 
    all_actual_predicted_list = defaultdict(list)
    precision = dict()
    recall= dict()
    no_of_relevant_items = 0 
    no_of_recommended_items_at_top_n = 0 
    no_of_relevant_recommended_items_at_top_n = 0  
    for uid, iid, true_r, est, _ in predictions:
        all_actual_predicted_list[uid].append((est, true_r)) 
    for uid, user_ratings in all_actual_predicted_list.items():
        user_ratings.sort(key=lambda x: x[0], reverse=True)
        no_of_relevant_items = sum((true_r >= rating_threshold) for (_, true_r) in user_ratings)
        no_of_recommended_items_at_top_n = sum((est >= rating_threshold) for (est, _) in user_ratings[:topn])
        no_of_relevant_recommended_items_at_top_n = sum(((true_r >= rating_threshold) and (est >= rating_threshold)) for (est, true_r) in user_ratings[:topn])
        precision[uid] = no_of_relevant_recommended_items_at_top_n / no_of_recommended_items_at_top_n if no_of_recommended_items_at_top_n != 0 else 1
        recall[uid] = no_of_relevant_recommended_items_at_top_n / no_of_relevant_items if no_of_relevant_items != 0 else 1
    return precision, recall 

rating_threshold=3 
precision_recall_at_n = [] 
for topn in range(2,20):
    precision, recall = get_precision_recall_at_n(predictions,topn,rating_threshold)
    precision_at_n = sum(prec for prec in precision.values()) / len(precision)

    recall_at_n = sum(rec for rec in recall.values()) / len(recall)
    precision_recall_at_n.append({'topN' : topn, 'Precision' : precision_at_n, 'Recall': recall_at_n})
for n in range(3,9):
    print(precision_recall_at_n[n])
#get user high rated and liked movies
all_book_df_details = pd.merge(df_users,df_books, on='book_id', how='inner')
all_book_df_details = all_book_df_details.sort_values(['user_id','rating'],ascending=[True, False])
print(all_book_df_details.loc[all_book_df_details['user_id'] == "c5823767a1a164cd8e9d029f1806f2aa"].head(10)) #user 10 top 10 rated movies
#user 10 top 10 movie recommendations list 
print(top_n_recommendations_df.loc[top_n_recommendations_df['user'] == "c5823767a1a164cd8e9d029f1806f2aa"].head(10))
# Out:
# {'topN': 5, 'Precision': 0.9517699774203956, 'Recall': 0.6212772639304668}
# {'topN': 6, 'Precision': 0.9516893207602612, 'Recall': 0.6223076123423367}
# {'topN': 7, 'Precision': 0.9516432616422433, 'Recall': 0.6229383976517086}
# {'topN': 8, 'Precision': 0.9516038149718615, 'Recall': 0.623335690100741}
# {'topN': 9, 'Precision': 0.9515805827324656, 'Recall': 0.6235884657850648}
# {'topN': 10, 'Precision': 0.9515682394968779, 'Recall': 0.6237658112812048}
#                                  user_id   book_id  rating        isbn  \
# 44569   c5823767a1a164cd8e9d029f1806f2aa     30119       5  0060513039
# 76521   c5823767a1a164cd8e9d029f1806f2aa  24769928       5  193644965X
# 147224  c5823767a1a164cd8e9d029f1806f2aa     30118       5  0060513063
# 218900  c5823767a1a164cd8e9d029f1806f2aa      1420       5  0521618746
# 257964  c5823767a1a164cd8e9d029f1806f2aa  17707772       5  1594204780
# 266848  c5823767a1a164cd8e9d029f1806f2aa  20821284       5  0399252517
# 337192  c5823767a1a164cd8e9d029f1806f2aa      1381       5  0143039954
# 392178  c5823767a1a164cd8e9d029f1806f2aa  16180680       5  0615729207
# 437526  c5823767a1a164cd8e9d029f1806f2aa  22151696       5  1449461077
# 446046  c5823767a1a164cd8e9d029f1806f2aa     95819       5  0805005013
#
#         text_reviews_count series country_code language_code  \
# 44569                 8950     []           US           eng
# 76521                   25     []           US           eng
# 147224                2222     []           US           eng
# 218900                5737     []           US           eng
# 257964                 540     []           US           eng
# 266848                4929     []           US           eng
# 337192                5608     []           US           eng
# 392178                   7     []           US           eng
# 437526                1186     []           US           eng
# 446046                 286     []           US           eng
#
#                                           popular_shelves asin  ...  \
# 44569   [{'count': '20447', 'name': 'to-read'}, {'coun...  NaN  ...
# 76521   [{'count': '1106', 'name': 'to-read'}, {'count...  NaN  ...
# 147224  [{'count': '95074', 'name': 'to-read'}, {'coun...  NaN  ...
# 218900  [{'count': '1659', 'name': 'school'}, {'count'...  NaN  ...
# 257964  [{'count': '6190', 'name': 'to-read'}, {'count...  NaN  ...
# 266848  [{'count': '1711', 'name': 'poetry'}, {'count'...  NaN  ...
# 337192  [{'count': '247044', 'name': 'to-read'}, {'cou...  NaN  ...
# 392178  [{'count': '403', 'name': 'to-read'}, {'count'...  NaN  ...
# 437526  [{'count': '28986', 'name': 'to-read'}, {'coun...  NaN  ...
# 446046  [{'count': '32878', 'name': 'to-read'}, {'coun...  NaN  ...
#
#                isbn13  publication_month               edition_information  \
# 44569   9780060513030               11.0                               NaN
# 76521   9781936449651                1.0                               NaN
# 147224  9780060513061               10.0  20th Anniversary Edition with CD
# 218900  9780521618748                8.0                               NaN
# 257964  9781594204784               10.0                               NaN
# 266848  9780399252518                8.0                               NaN
# 337192  9780143039952               11.0                               NaN
# 392178  9780615729206               11.0                               NaN
# 437526  9781449461072                9.0                               NaN
# 446046  9780805005011                3.0                               NaN
#
#        publication_year                                                url  \
# 44569            2002.0  https://www.goodreads.com/book/show/30119.Wher...
# 76521            2015.0  https://www.goodreads.com/book/show/24769928-c...
# 147224           2002.0  https://www.goodreads.com/book/show/30118.A_Li...
# 218900           2005.0    https://www.goodreads.com/book/show/1420.Hamlet
# 257964           2013.0  https://www.goodreads.com/book/show/17707772-d...
# 266848           2014.0  https://www.goodreads.com/book/show/20821284-b...
# 337192           2006.0  https://www.goodreads.com/book/show/1381.The_O...
# 392178           2012.0  https://www.goodreads.com/book/show/16180680-u...
# 437526           2014.0  https://www.goodreads.com/book/show/22151696-l...
# 446046           1979.0  https://www.goodreads.com/book/show/95819.The_...
#
#                                                 image_url ratings_count  \
# 44569   https://images.gr-assets.com/books/1168052448m...       1029527
# 76521   https://images.gr-assets.com/books/1442518972m...            38
# 147224  https://images.gr-assets.com/books/1427169918m...        304689
# 218900  https://images.gr-assets.com/books/1351051208m...        526122
# 257964  https://images.gr-assets.com/books/1367269165m...          3552
# 266848  https://images.gr-assets.com/books/1424308405m...         35473
# 337192  https://images.gr-assets.com/books/1390173285m...        680823
# 392178  https://images.gr-assets.com/books/1354240180m...            32
# 437526  https://images.gr-assets.com/books/1404192714m...         15314
# 446046  https://s.gr-assets.com/assets/nophoto/book/11...         34047
#
#          work_id                                              title  \
# 44569      30518                            Where the Sidewalk Ends
# 76521   44400954  Constructed of Magic: And Other Poems on the I...
# 147224    142009                               A Light in the Attic
# 218900   1885548                                             Hamlet
# 257964  24757302                                          Dog Songs
# 266848  39959105                                Brown Girl Dreaming
# 337192   3356006                                        The Odyssey
# 392178  22056228                                      Utterly Loved
# 437526  41496977                                          Lullabies
# 446046    366182                         The Poetry of Robert Frost
#
#                                      title_without_series
# 44569                             Where the Sidewalk Ends
# 76521   Constructed of Magic: And Other Poems on the I...
# 147224                               A Light in the Attic
# 218900                                             Hamlet
# 257964                                          Dog Songs
# 266848                                Brown Girl Dreaming
# 337192                                        The Odyssey
# 392178                                      Utterly Loved
# 437526                                          Lullabies
# 446046                         The Poetry of Robert Frost
#
# [10 rows x 31 columns]
#                                     user   book_id  predicted_rating  \
# 105529  c5823767a1a164cd8e9d029f1806f2aa     30118               5.0
# 111584  c5823767a1a164cd8e9d029f1806f2aa      2547               5.0
# 136464  c5823767a1a164cd8e9d029f1806f2aa  30325231               5.0
# 192516  c5823767a1a164cd8e9d029f1806f2aa  13324301               5.0
# 236185  c5823767a1a164cd8e9d029f1806f2aa     26596               5.0
# 249878  c5823767a1a164cd8e9d029f1806f2aa    294399               5.0
# 251091  c5823767a1a164cd8e9d029f1806f2aa    321538               5.0
# 266327  c5823767a1a164cd8e9d029f1806f2aa  26114416               5.0
# 271224  c5823767a1a164cd8e9d029f1806f2aa    151717               5.0
# 286197  c5823767a1a164cd8e9d029f1806f2aa  22253712               5.0
#
#               isbn  text_reviews_count      series country_code language_code  \
# 105529  0060513063                2222          []           US           eng
# 111584  000100039X                4280          []           US           eng
# 136464  0692649093                 228          []           US           eng
# 192516         NaN                   9  ['562788']           US           eng
# 236185  0871401525                 181          []           US           eng
# 249878  0393979261                  78          []           US           eng
# 251091  0679731970                  62          []           US           eng
# 266327  0865478201                 151          []           US           eng
# 271224  1573229148                  77          []           US           eng
# 286197  0393070239                  20          []           US           eng
#
#                                           popular_shelves asin  ...  \
# 105529  [{'count': '95074', 'name': 'to-read'}, {'coun...  NaN  ...
# 111584  [{'count': '1941', 'name': 'poetry'}, {'count'...  NaN  ...
# 136464  [{'count': '7828', 'name': 'to-read'}, {'count...  NaN  ...
# 192516  [{'count': '608', 'name': 'to-read'}, {'count'...  NaN  ...
# 236185  [{'count': '22872', 'name': 'to-read'}, {'coun...  NaN  ...
# 249878  [{'count': '280', 'name': 'poetry'}, {'count':...  NaN  ...
# 251091  [{'count': '4488', 'name': 'to-read'}, {'count...  NaN  ...
# 266327  [{'count': '3016', 'name': 'to-read'}, {'count...  NaN  ...
# 271224  [{'count': '1872', 'name': 'to-read'}, {'count...  NaN  ...
# 286197  [{'count': '134', 'name': 'to-read'}, {'count'...  NaN  ...
#
#                isbn13  publication_month               edition_information  \
# 105529  9780060513061               10.0  20th Anniversary Edition with CD
# 111584  9780001000391                1.0                               NaN
# 136464  9780692649091                5.0                               NaN
# 192516            NaN                NaN                               NaN
# 236185  9780871401526                NaN                               NaN
# 249878  9780393979268                NaN                       2nd Edition
# 251091  9780679731979                4.0                               NaN
# 266327  9780865478206                NaN                               NaN
# 271224  9781573229142                4.0                               NaN
# 286197  9780393070231                4.0                               NaN
#
#        publication_year                                                url  \
# 105529           2002.0  https://www.goodreads.com/book/show/30118.A_Li...
# 111584           2010.0  https://www.goodreads.com/book/show/2547.The_P...
# 136464           2016.0  https://www.goodreads.com/book/show/30325231-t...
# 192516           2010.0  https://www.goodreads.com/book/show/13324301-t...
# 236185           1994.0  https://www.goodreads.com/book/show/26596.Comp...
# 249878              NaN  https://www.goodreads.com/book/show/294399.In_...
# 251091           1991.0  https://www.goodreads.com/book/show/321538.Col...
# 266327              NaN  https://www.goodreads.com/book/show/26114416-t...
# 271224           2002.0  https://www.goodreads.com/book/show/151717.Cro...
# 286197           2015.0  https://www.goodreads.com/book/show/22253712-d...
#
#                                                 image_url ratings_count  \
# 105529  https://images.gr-assets.com/books/1427169918m...        304689
# 111584  https://images.gr-assets.com/books/1355046521m...        145579
# 136464  https://images.gr-assets.com/books/1464713743m...          1790
# 192516  https://images.gr-assets.com/books/1460519739m...           123
# 236185  https://images.gr-assets.com/books/1355093052m...         18787
# 249878  https://s.gr-assets.com/assets/nophoto/book/11...          2599
# 251091  https://images.gr-assets.com/books/1394965562m...          5180
# 266327  https://images.gr-assets.com/books/1450039589m...           956
# 271224  https://images.gr-assets.com/books/1309212064m...           589
# 286197  https://images.gr-assets.com/books/1404959040m...           157
#
#          work_id                                              title  \
# 105529    142009                               A Light in the Attic
# 111584   2938937                                        The Prophet
# 136464  50818848                               The Chaos of Longing
# 192516  18531080               The Tiny Book of Tiny Stories - 2010
# 236185    175882                          Complete Poems, 1904-1962
# 249878   1194370                                        In Memoriam
# 251091    581787                                    Collected Poems
# 266327  46061288                               The Hatred of Poetry
# 271224    146437  Crossing the Unknown Sea: Work as a Pilgrimage...
# 286197  26659483                                   Deep Lane: Poems
#
#                                      title_without_series
# 105529                               A Light in the Attic
# 111584                                        The Prophet
# 136464                               The Chaos of Longing
# 192516               The Tiny Book of Tiny Stories - 2010
# 236185                          Complete Poems, 1904-1962
# 249878                                        In Memoriam
# 251091                                    Collected Poems
# 266327                               The Hatred of Poetry
# 271224  Crossing the Unknown Sea: Work as a Pilgrimage...
# 286197                                   Deep Lane: Poems
#
# [10 rows x 31 columns]

# %%
top_books=all_book_df_details.loc[all_book_df_details['user_id'] == "c5823767a1a164cd8e9d029f1806f2aa"].head(10)
top_books_with_descriptions = top_books.merge(df_books[['book_id', 'description']], on='book_id', how='left')

# %%
top_books_with_descriptions.columns
# Out:
# Index(['user_id', 'book_id', 'rating', 'isbn', 'text_reviews_count', 'series',
#        'country_code', 'language_code', 'popular_shelves', 'asin', 'is_ebook',
#        'average_rating', 'kindle_asin', 'similar_books', 'description_x',
#        'format', 'link', 'authors', 'publisher', 'num_pages',
#        'publication_day', 'isbn13', 'publication_month', 'edition_information',
#        'publication_year', 'url', 'image_url', 'ratings_count', 'work_id',
#        'title', 'title_without_series', 'description_y'],
#       dtype='object')

# %%
top_books_with_descriptions=top_books_with_descriptions[['user_id', 'book_id', 'rating', 'title', 'description_y']]

# %%
top_books_with_descriptions.head(10)
# Out:
#                             user_id   book_id  rating  \
# 0  c5823767a1a164cd8e9d029f1806f2aa     30119       5
# 1  c5823767a1a164cd8e9d029f1806f2aa  24769928       5
# 2  c5823767a1a164cd8e9d029f1806f2aa     30118       5
# 3  c5823767a1a164cd8e9d029f1806f2aa      1420       5
# 4  c5823767a1a164cd8e9d029f1806f2aa  17707772       5
# 5  c5823767a1a164cd8e9d029f1806f2aa  20821284       5
# 6  c5823767a1a164cd8e9d029f1806f2aa      1381       5
# 7  c5823767a1a164cd8e9d029f1806f2aa  16180680       5
# 8  c5823767a1a164cd8e9d029f1806f2aa  22151696       5
# 9  c5823767a1a164cd8e9d029f1806f2aa     95819       5
#
#                                                title  \
# 0                            Where the Sidewalk Ends
# 1  Constructed of Magic: And Other Poems on the I...
# 2                               A Light in the Attic
# 3                                             Hamlet
# 4                                          Dog Songs
# 5                                Brown Girl Dreaming
# 6                                        The Odyssey
# 7                                      Utterly Loved
# 8                                          Lullabies
# 9                         The Poetry of Robert Frost
#
#                                        description_y
# 0  Where the Sidewalk Ends turns forty! Celebrate...
# 1  What Would Life be Like if You Knew You Were a...
# 2  Last night while I lay thinking here\nSome Wha...
# 3  One of the greatest plays of all time, the com...
# 4  Mary Oliver's Dog Songsis a celebration of the...
# 5  Jacqueline Woodson, one of today's finest writ...
# 6  Literature's grandest evocation of life's jour...
# 7  Foreword by New York Times and USA Today Bests...
# 8  A sequel to the hugely popular, best-selling L...
# 9  The only comprehensive gathering of Frost's pu...

# %%
filtered_df = top_n_recommendations_df[top_n_recommendations_df['user'] == "c5823767a1a164cd8e9d029f1806f2aa"].head(10)
filtered_df=filtered_df[['user', 'book_id', 'predicted_rating', 'title', 'description']]
filtered_df.head(10)
# Out:
#                                     user   book_id  predicted_rating  \
# 105529  c5823767a1a164cd8e9d029f1806f2aa     30118               5.0
# 111584  c5823767a1a164cd8e9d029f1806f2aa      2547               5.0
# 136464  c5823767a1a164cd8e9d029f1806f2aa  30325231               5.0
# 192516  c5823767a1a164cd8e9d029f1806f2aa  13324301               5.0
# 236185  c5823767a1a164cd8e9d029f1806f2aa     26596               5.0
# 249878  c5823767a1a164cd8e9d029f1806f2aa    294399               5.0
# 251091  c5823767a1a164cd8e9d029f1806f2aa    321538               5.0
# 266327  c5823767a1a164cd8e9d029f1806f2aa  26114416               5.0
# 271224  c5823767a1a164cd8e9d029f1806f2aa    151717               5.0
# 286197  c5823767a1a164cd8e9d029f1806f2aa  22253712               5.0
#
#                                                     title  \
# 105529                               A Light in the Attic
# 111584                                        The Prophet
# 136464                               The Chaos of Longing
# 192516               The Tiny Book of Tiny Stories - 2010
# 236185                          Complete Poems, 1904-1962
# 249878                                        In Memoriam
# 251091                                    Collected Poems
# 266327                               The Hatred of Poetry
# 271224  Crossing the Unknown Sea: Work as a Pilgrimage...
# 286197                                   Deep Lane: Poems
#
#                                               description
# 105529  Last night while I lay thinking here\nSome Wha...
# 111584  Kahlil Gibran's masterpiece, The Prophet, is o...
# 136464  The Chaos of Longingis a prose and poetry coll...
# 192516                                                NaN
# 236185  At the time of his death in 1962, E. E. Cummin...
# 249878  In Memoriam is Tennyson's tribute to his frien...
# 251091  Between 1927 and his death in 1973, W. H. Aude...
# 266327  No art has been denounced as often as poetry. ...
# 271224  Crossing the Unknown Seais about reuniting the...
# 286197  Deep Lane is a book of descents: into the eart...
